# %%
import polarizability as pol
import staticraman as raman
import numpy as np
from pyscf import gto, dft, grad, scf

mol = gto.M(atom='O 0.0000000 0.0000000 0.1172700; H 0.0000000 0.7569520 -0.4690790; H 0.0000000 -0.7569520 -0.4690790', basis='ccpvdz')

result = raman.get_raman_activities_RHF(mol)
print(result)
# Out:
# pyscf plugins found in
# /Users/royalty/Desktop/Summer_Research/pyscf
# When PYTHONPATH is set, it is recommended to load these plugins through the environment variable PYSCF_EXT_PATH
# /Users/royalty/Desktop/Summer_Research/pyscf/pyscf/dft/libxc.py:772: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, the same to the B3LYP functional in Gaussian and ORCA (issue 1480). To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '
# converged SCF energy = -76.026785941794
# converged SCF energy = -76.0267924945566
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00000, -0.80826
# converged SCF energy = -76.0267879343214
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00000, -0.80826
# <class 'polarizability.ModifiedRHF'> does not have attributes  e_field
# converged SCF energy = -76.0267864142431
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80826
# converged SCF energy = -76.0267879343214
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00000, -0.80826
# converged SCF energy = -76.0267924945566
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00000, -0.80826
# converged SCF energy = -76.0268002424969
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.01383, -0.80823
# converged SCF energy = -76.0267898712809
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00691, -0.80825
# converged SCF energy = -76.0267864142431
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80826
# converged SCF energy = -76.026789871281
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00691, -0.80825
# converged SCF energy = -76.0268002424969
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.01383, -0.80823
# converged SCF energy = -76.028417111733
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81840
# converged SCF energy = -76.0275992280341
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81334
# converged SCF energy = -76.0267864142431
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80826
# converged SCF energy = -76.0259786809573
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80318
# converged SCF energy = -76.0251760388429
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.79808
# converged SCF energy = -76.0267924779957
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00000, -0.80880
# converged SCF energy = -76.0267879176873
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00000, -0.80880
# converged SCF energy = -76.0267863975846
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80880
# converged SCF energy = -76.0267879176875
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00000, -0.80880
# converged SCF energy = -76.0267924779957
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00000, -0.80880
# converged SCF energy = -76.0268002229818
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.01383, -0.80877
# converged SCF energy = -76.0267898539085
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00691, -0.80879
# converged SCF energy = -76.0267863975846
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80880
# converged SCF energy = -76.0267898539084
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00691, -0.80879
# converged SCF energy = -76.0268002229818
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.01383, -0.80877
# converged SCF energy = -76.0284161753102
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.81895
# converged SCF energy = -76.0275987493286
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81388
# converged SCF energy = -76.0267863975846
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80880
# converged SCF energy = -76.0259791306879
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80371
# converged SCF energy = -76.0251769593166
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.79861
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.): -0.00608,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.): -0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.):  0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.):  0.00608,  0.00000, -0.80934
# converged SCF energy = -76.026799764352
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.01382, -0.80931
# converged SCF energy = -76.0267893974098
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00691, -0.80933
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.0267893974099
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00691, -0.80933
# converged SCF energy = -76.0267997643519
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01382, -0.80931
# converged SCF energy = -76.0284147989718
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81950
# converged SCF energy = -76.0275978310967
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.81443
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.025979141692
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80425
# converged SCF energy = -76.0251774414731
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.79914
# converged SCF energy = -76.0267911269774
# Dipole moment(X, Y, Z, A.U.): -0.00608,  0.00000, -0.80988
# converged SCF energy = -76.0267865665246
# Dipole moment(X, Y, Z, A.U.): -0.00304,  0.00000, -0.80988
# converged SCF energy = -76.0267850463737
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80988
# converged SCF energy = -76.0267865665245
# Dipole moment(X, Y, Z, A.U.):  0.00304,  0.00000, -0.80988
# converged SCF energy = -76.0267911269774
# Dipole moment(X, Y, Z, A.U.):  0.00608,  0.00000, -0.80988
# converged SCF energy = -76.026798866102
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.01382, -0.80985
# converged SCF energy = -76.0267885012802
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00691, -0.80987
# converged SCF energy = -76.0267850463737
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80988
# converged SCF energy = -76.0267885012802
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00691, -0.80987
# converged SCF energy = -76.0267988661021
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.01382, -0.80985
# converged SCF energy = -76.0284129822167
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.82005
# converged SCF energy = -76.0275964728359
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.81497
# converged SCF energy = -76.0267850463737
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80988
# converged SCF energy = -76.0259787134623
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80478
# converged SCF energy = -76.0251774848043
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.79967
# converged SCF energy = -76.0267897915116
# Dipole moment(X, Y, Z, A.U.): -0.00608,  0.00000, -0.81042
# converged SCF energy = -76.0267852309869
# Dipole moment(X, Y, Z, A.U.): -0.00304,  0.00000, -0.81042
# converged SCF energy = -76.0267837108122
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.81042
# converged SCF energy = -76.0267852309869
# Dipole moment(X, Y, Z, A.U.):  0.00304,  0.00000, -0.81042
# converged SCF energy = -76.0267897915118
# Dipole moment(X, Y, Z, A.U.):  0.00608,  0.00000, -0.81042
# converged SCF energy = -76.026797527729
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.01382, -0.81039
# converged SCF energy = -76.0267871650159
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00691, -0.81041
# converged SCF energy = -76.0267837108122
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.81042
# converged SCF energy = -76.0267871650158
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00691, -0.81041
# converged SCF energy = -76.0267975277289
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01382, -0.81039
# converged SCF energy = -76.0284107245453
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.82060
# converged SCF energy = -76.0275946740445
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.81551
# converged SCF energy = -76.0267837108122
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.81042
# converged SCF energy = -76.0259778454934
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80532
# converged SCF energy = -76.0251770888013
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80020
# converged SCF energy = -76.0267196711882
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00000, -0.80988
# converged SCF energy = -76.0267151116421
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00000, -0.80988
# converged SCF energy = -76.0267135917932
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80988
# converged SCF energy = -76.026715111642
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00000, -0.80988
# converged SCF energy = -76.0267196711883
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00000, -0.80988
# converged SCF energy = -76.0267274724235
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.01388, -0.80985
# converged SCF energy = -76.0267170619251
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00694, -0.80988
# converged SCF energy = -76.0267135917932
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80988
# converged SCF energy = -76.026717061925
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00694, -0.80988
# converged SCF energy = -76.0267274724235
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01388, -0.80985
# converged SCF energy = -76.0283406236229
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.82007
# converged SCF energy = -76.0275245616335
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.81498
# converged SCF energy = -76.0267135917932
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80988
# converged SCF energy = -76.025907724775
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80478
# converged SCF energy = -76.0251069713194
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.79966
# converged SCF energy = -76.0267568997778
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00000, -0.80961
# converged SCF energy = -76.0267523398136
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00000, -0.80961
# converged SCF energy = -76.0267508198256
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80961
# converged SCF energy = -76.0267523398136
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00000, -0.80961
# converged SCF energy = -76.026756899778
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00000, -0.80961
# converged SCF energy = -76.0267646713843
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.01385, -0.80958
# converged SCF energy = -76.0267542826895
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00693, -0.80961
# converged SCF energy = -76.0267508198256
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80961
# converged SCF energy = -76.0267542826896
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00693, -0.80961
# converged SCF energy = -76.0267646713842
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01385, -0.80958
# converged SCF energy = -76.0283787647491
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81978
# converged SCF energy = -76.0275622496086
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.81470
# converged SCF energy = -76.0267508198256
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.80961
# converged SCF energy = -76.0259444860467
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.80451
# converged SCF energy = -76.0251432589875
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.79940
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.): -0.00608,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.): -0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.):  0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.):  0.00608,  0.00000, -0
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00045, -0.80425
# converged SCF energy = -76.0251763308011
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00044, -0.79914
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.): -0.00608,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.): -0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.0267874619232
# Dipole moment(X, Y, Z, A.U.):  0.00304,  0.00000, -0.80934
# converged SCF energy = -76.0267920223041
# Dipole moment(X, Y, Z, A.U.):  0.00608,  0.00000, -0.80934
# converged SCF energy = -76.026799764352
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.01382, -0.80931
# converged SCF energy = -76.0267893974098
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00691, -0.80933
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.0267893974099
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00691, -0.80933
# converged SCF energy = -76.0267997643519
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01382, -0.80931
# converged SCF energy = -76.0284147989718
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00000, -0.81950
# converged SCF energy = -76.0275978310967
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00000, -0.81443
# converged SCF energy = -76.0267859417965
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.80934
# converged SCF energy = -76.025979141692
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00000, -0.80425
# converged SCF energy = -76.0251774414731
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00000, -0.79914
# converged SCF energy = -76.0267909115776
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00046, -0.80934
# converged SCF energy = -76.0267863511962
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00046, -0.80934
# converged SCF energy = -76.0267848310691
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00046, -0.80934
# converged SCF energy = -76.0267863511963
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00046, -0.80934
# converged SCF energy = -76.0267909115776
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00046, -0.80934
# converged SCF energy = -76.0267975581254
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.01428, -0.80933
# converged SCF energy = -76.0267877389616
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00737, -0.80934
# converged SCF energy = -76.0267848310691
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00046, -0.80934
# converged SCF energy = -76.0267888344122
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.00645, -0.80933
# converged SCF energy = -76.0267997491594
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.01337, -0.80929
# converged SCF energy = -76.0284136882138
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00048, -0.81950
# converged SCF energy = -76.0275967203511
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00047, -0.81443
# converged SCF energy = -76.0267848310691
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00046, -0.80934
# converged SCF energy = -76.0259780309892
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00045, -0.80425
# converged SCF energy = -76.0251763308012
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00044, -0.79914
# converged SCF energy = -76.0267875793722
# Dipole moment(X, Y, Z, A.U.): -0.00608, -0.00091, -0.80934
# converged SCF energy = -76.0267830189895
# Dipole moment(X, Y, Z, A.U.): -0.00304, -0.00091, -0.80934
# converged SCF energy = -76.026781498862
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00091, -0.80934
# converged SCF energy = -76.0267830189894
# Dipole moment(X, Y, Z, A.U.):  0.00304, -0.00091, -0.80934
# converged SCF energy = -76.0267875793721
# Dipole moment(X, Y, Z, A.U.):  0.00608, -0.00091, -0.80934
# converged SCF energy = -76.0267931304567
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.01474, -0.80934
# converged SCF energy = -76.0267838590435
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00783, -0.80935
# converged SCF energy = -76.026781498862
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00091, -0.80934
# converged SCF energy = -76.0267860499429
# Dipole moment(X, Y, Z, A.U.): -0.00000,  0.00600, -0.80932
# converged SCF energy = -76.0267975125211
# Dipole moment(X, Y, Z, A.U.):  0.00000,  0.01291, -0.80927
# converged SCF energy = -76.0284103559142
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00095, -0.81950
# converged SCF energy = -76.0275933880886
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00093, -0.81443
# converged SCF energy = -76.026781498862
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00091, -0.80934
# converged SCF energy = -76.0259746988557
# Dipole moment(X, Y, Z, A.U.):  0.00000, -0.00090, -0.80425
# converged SCF energy = -76.02517299876
# Dipole moment(X, Y, Z, A.U.): -0.00000, -0.00088, -0.79914
# [ 5.18504963 74.48608733 37.54201256]
